# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/LEE/python/빅데이터예측모델링/데이터수집(서울만)/지코변날역인(채운거)(최종).csv')

# %%
x = df.describe()

# %%
x.to_csv('C:/Users/LEE/python/빅데이터예측모델링/데이터수집(서울만)/데이터분석.csv', encoding = 'utf-8-sig', index_label = True, index = True)

# %%
x
# Out:
#                date        subway       전날누적확진자           d+1           d+2  \
# count  1.897500e+04   18975.00000  18975.000000  18975.000000  18975.000000
# mean   2.019703e+07  168490.31610    121.672622      1.312885      1.307615
# std    6.116574e+03  122308.98233    259.648379      3.438105      3.434624
# min    2.019020e+07    7965.00000      0.000000      0.000000      0.000000
# 25%    2.019081e+07   79735.00000      0.000000      0.000000      0.000000
# 50%    2.020022e+07  140876.00000      0.000000      0.000000      0.000000
# 75%    2.020082e+07  218324.50000     91.000000      1.000000      1.000000
# max    2.021023e+07  765186.00000   1649.000000     81.000000     81.000000
#
#                 d+3           d+4           d+5           d+6           d+7  \
# count  18975.000000  18975.000000  18975.000000  18975.000000  18975.000000
# mean       1.301186      1.294967      1.289170      1.282372      1.276838
# ...
